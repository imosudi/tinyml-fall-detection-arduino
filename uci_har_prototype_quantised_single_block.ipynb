# %%
# !pip install tensorflow-model-optimization
# !pip install ai-edge-litert

# UCI HAR baseline prototype: 6-class model for domain validation only.

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os
import tensorflow_model_optimization as tfmot
import warnings
# Suppress the specific statistics deprecation warning
warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    message=".*Statistics for quantized inputs were expected.*"
)

# %matplotlib inline

from google.colab import drive

google_drive_path = "/content/drive"

## Mount Google Drive
drive.mount(google_drive_path)

## Project custom drive path
my_path = "AG/FH/study/AI_IoT/node/milestone2"

## Declare project home directory
project_path = f"{google_drive_path}/MyDrive/{my_path}"
os.makedirs(project_path, exist_ok=True)

## Create output directory
### Full Features
os.makedirs(f"{project_path}/output/full_model", exist_ok=True)
os.makedirs(f"{project_path}/output/full_model/models", exist_ok=True)
### Reduced Features
os.makedirs(f"{project_path}/output/reduced", exist_ok=True)
os.makedirs(f"{project_path}/output/reduced/models", exist_ok=True)


## Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

## Features
TARGET_NAMES = ["WALKING", "WALKING_UP", "WALKING_DOWN", "SITTING", "STANDING", "LAYING"]
NUM_CLASSES  = 6

# Functions
## Data loading
def load_uci_har_raw(data_path=f"{project_path}/UCI-HAR_Dataset"):
    acc_axes  = ["body_acc_x",  "body_acc_y",  "body_acc_z"]
    gyro_axes = ["body_gyro_x", "body_gyro_y", "body_gyro_z"]

    def _load_split(split):
        arrays = []
        for name in acc_axes + gyro_axes:
            path = f"{data_path}/{split}/InertialSignals/{name}_{split}.txt"
            arrays.append(np.loadtxt(path))
        return np.stack(arrays, axis=-1)

    X_train = _load_split("train")
    X_test  = _load_split("test")

    y_train = np.loadtxt(f"{data_path}/train/y_train.txt", dtype=int)
    y_test  = np.loadtxt(f"{data_path}/test/y_test.txt", dtype=int)

    y_train -= 1
    y_test  -= 1

    return X_train, y_train, X_test, y_test

##  Feature extraction
def extract_features_window(window):
    feats = []
    for axis in range(6):
        feats.append(np.mean(window[:, axis]))
        feats.append(np.std(window[:, axis]))
    for axis in range(6):
        feats.append(np.min(window[:, axis]))
        feats.append(np.max(window[:, axis]))

    feats.append(np.sum(np.abs(window[:, :3])) / window.shape[0])
    feats.append(np.sum(np.abs(window[:, 3:])) / window.shape[0])

    acc_mag = np.linalg.norm(window[:, :3], axis=1)
    feats.append(np.mean(acc_mag))
    feats.append(np.std(acc_mag))

    return np.array(feats)


## Models Training
X_train_raw, y_train, X_test_raw, y_test = load_uci_har_raw()

X_train_feat = np.array([extract_features_window(w) for w in X_train_raw])
X_test_feat  = np.array([extract_features_window(w) for w in X_test_raw])

print(f"Feature shape - train: {X_train_feat.shape}, test: {X_test_feat.shape}")

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train_feat)
X_test_sc  = scaler.transform(X_test_feat)

complete_feature_model = models.Sequential([
    layers.Input(shape=(X_train_feat.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(NUM_CLASSES, activation="softmax"),
], name="complete_features_baseline")


## Model manipulations
complete_feature_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

complete_feature_model.summary()

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history = complete_feature_model.fit(
    X_train_sc, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_sc, y_test),
    callbacks=[early_stop],
    verbose=1,
)

## Save Model
complete_feature_model.save(f"{project_path}/output/full_model/models/complete_features_baseline.keras")
print("Saved complete_features_baseline.keras")


# Ploting Training vs Validation Loss & Accuracy
plt.figure(figsize=(12,8))

## Loss plot
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Complete Features Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
#plt.savefig(f"{project_path}/output/full_model/training_validation_curves.png", dpi=150)
#plt.show()


## Accuracy plot
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Complete Features  Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/training_curves.png", dpi=150)
plt.show()

print("Saved Complete Features training_curves.png")


## Evaluation
y_pred = np.argmax(complete_feature_model.predict(X_test_sc), axis=1)

print("\n" + classification_report(y_test, y_pred, target_names=TARGET_NAMES))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=TARGET_NAMES,
            yticklabels=TARGET_NAMES,
            cmap="Blues")

plt.title("Complete Features Confusion Matrix (Baseline model)")
plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/confusion_matrix.png", dpi=150)
plt.show()

print("Saved confusion_matrix.png")

# Quantisation
## Convert to LiteRT model
converter_base = tf.lite.TFLiteConverter.from_keras_model(complete_feature_model)
tflite_base_model = converter_base.convert()
## Save LiteRT model
with open(f"{project_path}/output/full_model/models/complete_features_model.tflite", "wb") as f:
    f.write(tflite_base_model)

print("Saved converted full features tflite.")


# Reduced Model

## 1. Label Mapping (6 → 2 classes)
## 0: stationary, 1: walking

def map_labels(y):
    mapped = []
    for label in y:
        if label in [0, 1, 2]:      # WALKING variants
            mapped.append(1)        # walking
        elif label in [3, 4, 5]:    # SITTING/STANDING/LAYING
            mapped.append(0)        # stationary
    return np.array(mapped)

y_train_mapped = map_labels(y_train)
y_test_mapped  = map_labels(y_test)

TARGET_NAMES_REDUCED = ["STATIONARY", "WALKING"]

print("Original classes:", np.unique(y_train))
print("Mapped classes:", np.unique(y_train_mapped))


## 2. Build Reduced Model
model_reduced = models.Sequential([
    layers.Input(shape=(X_train_sc.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(2, activation="softmax"),
], name="reduced_featues_baseline")

model_reduced.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model_reduced.summary()



## Train
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_reduced = model_reduced.fit(
    X_train_sc, y_train_mapped,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_sc, y_test_mapped),
    callbacks=[early_stop],
    verbose=1
)


## Plot Training Curves
plt.figure(figsize=(12,5))

## Loss
plt.subplot(1,2,1)
plt.plot(history_reduced.history['loss'], label='Train Loss')
plt.plot(history_reduced.history['val_loss'], label='Validation Loss')
plt.title('Reduced Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

## Accuracy
plt.subplot(1,2,2)
plt.plot(history_reduced.history['accuracy'], label='Train Accuracy')
plt.plot(history_reduced.history['val_accuracy'], label='Validation Accuracy')
plt.title('Reduced Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_training_curves.png", dpi=150)
plt.show()

print("Saved reduced_training_curves.png")


## 5. Evaluation
y_pred_reduced = np.argmax(model_reduced.predict(X_test_sc), axis=1)

print("\nReduced Model Classification Report:\n")
print(classification_report(y_test_mapped, y_pred_reduced, target_names=TARGET_NAMES_REDUCED))

cm_reduced = confusion_matrix(y_test_mapped, y_pred_reduced)

plt.figure(figsize=(6,5))
sns.heatmap(cm_reduced, annot=True, fmt="d",
            xticklabels=TARGET_NAMES_REDUCED,
            yticklabels=TARGET_NAMES_REDUCED,
            cmap="Blues")

plt.title("Reduced-Class Confusion Matrix (UCI Baseline)")
plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_confusion_matrix.png", dpi=150)
plt.show()

print("Saved reduced_confusion_matrix.png")


## Save Model
model_reduced.save(f"{project_path}/output/reduced/models/reduced_features_baseline.keras")
print("Saved uci_har_reduced_baseline.keras")


# Quantisation

## Convert complete features to LiteRT model
converter_base = tf.lite.TFLiteConverter.from_keras_model(complete_feature_model)
tflite_base_model = converter_base.convert()
## Save LiteRT model
with open(f"{project_path}/output/full_model/models/complete_features_model.tflite", "wb") as f:
    f.write(tflite_base_model)

print("Saved converted full features tflite.")



## Convert reduced features to LiteRT model                                                                                                                                                                                                                                                                                                                                  # Convert to LiteRT model
converter_base = tf.lite.TFLiteConverter.from_keras_model(model_reduced)
tflite_base_model = converter_base.convert()

## Save LiteRT model
with open(f"{project_path}/output/reduced/models/reduced_features_baseline.tflite", "wb") as f:
    f.write(tflite_base_model)

print("Saved converted full features tflite.")
# Out:
# Requirement already satisfied: tensorflow-model-optimization in /usr/local/lib/python3.12/dist-packages (0.8.0)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (0.1.10)
# Requirement already satisfied: numpy~=1.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.26.4)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (26.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (2.1.2)
# Requirement already satisfied: ai-edge-litert in /usr/local/lib/python3.12/dist-packages (2.1.4)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (1.2.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (25.12.19)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (1.26.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (5.29.6)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Feature shape - train: (7352, 28), test: (2947, 28)
# Model: "complete_features_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,126 (4.40 KB)
#  Trainable params: 1,126 (4.40 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.4221 - loss: 1.1885 - val_accuracy: 0.5280 - val_loss: 1.0110
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5698 - loss: 0.9055 - val_accuracy: 0.5826 - val_loss: 0.8886
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6138 - loss: 0.8260 - val_accuracy: 0.6013 - val_loss: 0.8324
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6308 - loss: 0.7835 - val_accuracy: 0.6176 - val_loss: 0.7961
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6485 - loss: 0.7545 - val_accuracy: 0.6308 - val_loss: 0.7701
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6621 - loss: 0.7321 - val_accuracy: 0.6410 - val_loss: 0.7496
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6771 - loss: 0.7132 - val_accuracy: 0.6468 - val_loss: 0.7332
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6904 - loss: 0.6967 - val_accuracy: 0.6573 - val_loss: 0.7196
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6984 - loss: 0.6818 - val_accuracy: 0.6597 - val_loss: 0.7081
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7084 - loss: 0.6686 - val_accuracy: 0.6678 - val_loss: 0.6982
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7189 - loss: 0.6566 - val_accuracy: 0.6709 - val_loss: 0.6895
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7262 - loss: 0.6458 - val_accuracy: 0.6797 - val_loss: 0.6816
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7315 - loss: 0.6359 - val_accuracy: 0.6831 - val_loss: 0.6747
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7372 - loss: 0.6268 - val_accuracy: 0.6861 - val_loss: 0.6683
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7443 - loss: 0.6182 - val_accuracy: 0.6932 - val_loss: 0.6623
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7477 - loss: 0.6103 - val_accuracy: 0.6949 - val_loss: 0.6571
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7530 - loss: 0.6028 - val_accuracy: 0.7011 - val_loss: 0.6520
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7575 - loss: 0.5957 - val_accuracy: 0.7061 - val_loss: 0.6475
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7622 - loss: 0.5890 - val_accuracy: 0.7133 - val_loss: 0.6431
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7670 - loss: 0.5825 - val_accuracy: 0.7177 - val_loss: 0.6389
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7712 - loss: 0.5765 - val_accuracy: 0.7214 - val_loss: 0.6348
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7741 - loss: 0.5709 - val_accuracy: 0.7251 - val_loss: 0.6311
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7763 - loss: 0.5655 - val_accuracy: 0.7282 - val_loss: 0.6280
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7799 - loss: 0.5605 - val_accuracy: 0.7326 - val_loss: 0.6249
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7821 - loss: 0.5557 - val_accuracy: 0.7346 - val_loss: 0.6222
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7835 - loss: 0.5512 - val_accuracy: 0.7370 - val_loss: 0.6195
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.5466 - val_accuracy: 0.7384 - val_loss: 0.6168
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7877 - loss: 0.5424 - val_accuracy: 0.7424 - val_loss: 0.6145
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7894 - loss: 0.5382 - val_accuracy: 0.7499 - val_loss: 0.6123
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7912 - loss: 0.5343 - val_accuracy: 0.7536 - val_loss: 0.6100
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7934 - loss: 0.5305 - val_accuracy: 0.7570 - val_loss: 0.6083
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7949 - loss: 0.5268 - val_accuracy: 0.7601 - val_loss: 0.6065
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7962 - loss: 0.5232 - val_accuracy: 0.7604 - val_loss: 0.6050
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7965 - loss: 0.5197 - val_accuracy: 0.7635 - val_loss: 0.6036
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7996 - loss: 0.5164 - val_accuracy: 0.7655 - val_loss: 0.6018
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8007 - loss: 0.5131 - val_accuracy: 0.7648 - val_loss: 0.6002
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8029 - loss: 0.5101 - val_accuracy: 0.7716 - val_loss: 0.5985
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8048 - loss: 0.5069 - val_accuracy: 0.7730 - val_loss: 0.5981
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8051 - loss: 0.5040 - val_accuracy: 0.7754 - val_loss: 0.5976
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8064 - loss: 0.5010 - val_accuracy: 0.7757 - val_loss: 0.5963
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8073 - loss: 0.4983 - val_accuracy: 0.7774 - val_loss: 0.5957
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8084 - loss: 0.4954 - val_accuracy: 0.7788 - val_loss: 0.5951
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8100 - loss: 0.4927 - val_accuracy: 0.7774 - val_loss: 0.5945
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8113 - loss: 0.4901 - val_accuracy: 0.7788 - val_loss: 0.5942
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8123 - loss: 0.4875 - val_accuracy: 0.7815 - val_loss: 0.5939
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8134 - loss: 0.4850 - val_accuracy: 0.7805 - val_loss: 0.5932
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8135 - loss: 0.4825 - val_accuracy: 0.7822 - val_loss: 0.5928
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8162 - loss: 0.4798 - val_accuracy: 0.7818 - val_loss: 0.5928
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8171 - loss: 0.4771 - val_accuracy: 0.7832 - val_loss: 0.5931
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8164 - loss: 0.4746 - val_accuracy: 0.7869 - val_loss: 0.5927
# Saved complete_features_baseline.keras
# Saved Complete Features training_curves.png
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
#               precision    recall  f1-score   support
#
#      WALKING       0.85      0.83      0.84       496
#   WALKING_UP       0.79      0.85      0.82       471
# WALKING_DOWN       0.93      0.90      0.91       420
#      SITTING       0.74      0.67      0.70       491
#     STANDING       0.85      0.61      0.71       532
#       LAYING       0.65      0.90      0.75       537
#
#     accuracy                           0.79      2947
#    macro avg       0.80      0.79      0.79      2947
# weighted avg       0.80      0.79      0.79      2947
# Saved confusion_matrix.png
# Saved artifact at '/tmp/tmpkcnypo7w'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28), dtype=tf.float32, name='keras_tensor_6')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   137172335908368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137172335912592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137175331681296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137172335902800: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved converted full features tflite.
# Original classes: [0 1 2 3 4 5]
# Mapped classes: [0 1]
# Model: "reduced_featues_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                 │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 994 (3.88 KB)
#  Trainable params: 994 (3.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9433 - loss: 0.1332 - val_accuracy: 0.9990 - val_loss: 0.0193
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0090 - val_accuracy: 0.9990 - val_loss: 0.0084
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9996 - loss: 0.0051 - val_accuracy: 0.9993 - val_loss: 0.0052
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9996 - loss: 0.0037 - val_accuracy: 0.9997 - val_loss: 0.0037
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 8.9205e-04
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 7.9524e-04
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 7.1647e-04
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 9.7786e-04 - val_accuracy: 1.0000 - val_loss: 6.4778e-04
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9999 - loss: 8.2363e-04 - val_accuracy: 1.0000 - val_loss: 5.8467e-04
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9999 - loss: 6.7539e-04 - val_accuracy: 1.0000 - val_loss: 5.2532e-04
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 5.4268e-04 - val_accuracy: 1.0000 - val_loss: 4.6821e-04
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - accuracy: 0.9999 - loss: 4.4034e-04 - val_accuracy: 1.0000 - val_loss: 4.1812e-04
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 1.0000 - loss: 3.6140e-04 - val_accuracy: 1.0000 - val_loss: 3.7070e-04
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 1.0000 - loss: 3.0277e-04 - val_accuracy: 1.0000 - val_loss: 3.3212e-04
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 1.0000 - loss: 2.5437e-04 - val_accuracy: 1.0000 - val_loss: 2.9934e-04
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 1.0000 - loss: 2.1777e-04 - val_accuracy: 1.0000 - val_loss: 2.7288e-04
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8421e-04 - val_accuracy: 1.0000 - val_loss: 2.4874e-04
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5768e-04 - val_accuracy: 1.0000 - val_loss: 2.2816e-04
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3515e-04 - val_accuracy: 1.0000 - val_loss: 2.1151e-04
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1665e-04 - val_accuracy: 1.0000 - val_loss: 1.9555e-04
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.0010e-04 - val_accuracy: 1.0000 - val_loss: 1.8123e-04
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.7113e-05 - val_accuracy: 1.0000 - val_loss: 1.7073e-04
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 7.5035e-05 - val_accuracy: 1.0000 - val_loss: 1.5954e-04
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.5237e-05 - val_accuracy: 1.0000 - val_loss: 1.4982e-04
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.6439e-05 - val_accuracy: 1.0000 - val_loss: 1.4098e-04
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.9276e-05 - val_accuracy: 1.0000 - val_loss: 1.3396e-04
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.2748e-05 - val_accuracy: 1.0000 - val_loss: 1.2639e-04
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.7208e-05 - val_accuracy: 1.0000 - val_loss: 1.1986e-04
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.2563e-05 - val_accuracy: 1.0000 - val_loss: 1.1465e-04
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.8298e-05 - val_accuracy: 1.0000 - val_loss: 1.0903e-04
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.4692e-05 - val_accuracy: 1.0000 - val_loss: 1.0313e-04
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1587e-05 - val_accuracy: 1.0000 - val_loss: 9.8520e-05
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8917e-05 - val_accuracy: 1.0000 - val_loss: 9.4379e-05
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6499e-05 - val_accuracy: 1.0000 - val_loss: 8.9813e-05
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4520e-05 - val_accuracy: 1.0000 - val_loss: 8.6124e-05
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.2669e-05 - val_accuracy: 1.0000 - val_loss: 8.1782e-05
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1142e-05 - val_accuracy: 1.0000 - val_loss: 7.8441e-05
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 9.7526e-06 - val_accuracy: 1.0000 - val_loss: 7.4522e-05
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 8.5817e-06 - val_accuracy: 1.0000 - val_loss: 7.1571e-05
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 7.4945e-06 - val_accuracy: 1.0000 - val_loss: 6.8909e-05
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 6.5819e-06 - val_accuracy: 1.0000 - val_loss: 6.4899e-05
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.7814e-06 - val_accuracy: 1.0000 - val_loss: 6.2238e-05
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.0731e-06 - val_accuracy: 1.0000 - val_loss: 5.9083e-05
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 4.4534e-06 - val_accuracy: 1.0000 - val_loss: 5.7361e-05
# Saved reduced_training_curves.png
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Reduced Model Classification Report:
#
#               precision    recall  f1-score   support
#
#   STATIONARY       1.00      1.00      1.00      1560
#      WALKING       1.00      1.00      1.00      1387
#
#     accuracy                           1.00      2947
#    macro avg       1.00      1.00      1.00      2947
# weighted avg       1.00      1.00      1.00      2947
# Saved reduced_confusion_matrix.png
# Saved uci_har_reduced_baseline.keras
# Saved artifact at '/tmp/tmpev7n9hch'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28), dtype=tf.float32, name='keras_tensor_9')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   137172324307536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137172324305040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137172324306768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   137172324309456: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved converted full features tflite.
