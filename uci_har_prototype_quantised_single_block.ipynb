# %%
# uci_har_prototype_quantised.ipynb
# UCI HAR Baseline Prototype with Quantisation
#

# !pip install tensorflow-model-optimization
# !pip install ai-edge-litert
# !pip install joblib
# Imports

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import math
import os
import tensorflow_model_optimization as tfmot
import json
import warnings

# Suppress specific warnings for cleaner output
warnings.filterwarnings(
    "ignore",
    category=UserWarning,
    message=".*Statistics for quantized inputs were expected.*"
)

# %matplotlib inline

# Mount Google Drive and Setup Paths

from google.colab import drive

google_drive_path = "/content/drive"

# Mount Google Drive
drive.mount(google_drive_path, force_remount=True)

# Project custom drive path
my_path = "AG/FH/study/AI_IoT/node/milestone2"

# Declare project home directory
project_path = f"{google_drive_path}/MyDrive/{my_path}"
os.makedirs(project_path, exist_ok=True)

# Create output directories for models and evaluation results
## Full Features
os.makedirs(f"{project_path}/output/full_model", exist_ok=True)
os.makedirs(f"{project_path}/output/full_model/models", exist_ok=True)
## Reduced Features
os.makedirs(f"{project_path}/output/reduced", exist_ok=True)
os.makedirs(f"{project_path}/output/reduced/models", exist_ok=True)


# Configuration and Reproducibility

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Class definitions for UCI HAR dataset (6 activities)
TARGET_NAMES = ["WALKING", "WALKING_UP", "WALKING_DOWN", "SITTING", "STANDING", "LAYING"]
NUM_CLASSES = 6

# Window parameters for feature extraction
WINDOW_SIZE = 128      # Number of samples per window (matches UCI HAR default)
WINDOW_STEP = 64       # Overlap between consecutive windows

# Data Loading Functions

def load_uci_har_raw(data_path=f"{project_path}/UCI-HAR_Dataset"):
    """
    Load raw UCI HAR dataset from text files.

    Args:
        data_path: Path to the UCI HAR Dataset directory

    Returns:
        X_train: Training data array of shape (7352, 128, 6)
        y_train: Training labels array of shape (7352,)
        X_test: Test data array of shape (2947, 128, 6)
        y_test: Test labels array of shape (2947,)
    """
    # Sensor column definitions
    acc_axes = ["body_acc_x", "body_acc_y", "body_acc_z"]
    gyro_axes = ["body_gyro_x", "body_gyro_y", "body_gyro_z"]

    def _load_split(split):
        """Load a specific split (train or test) from the dataset."""
        arrays = []
        for name in acc_axes + gyro_axes:
            path = f"{data_path}/{split}/InertialSignals/{name}_{split}.txt"
            arrays.append(np.loadtxt(path))
        # Stack sensor data along last dimension
        return np.stack(arrays, axis=-1)

    # Load training and test data
    X_train = _load_split("train")
    X_test = _load_split("test")

    # Load labels (1-indexed, convert to 0-indexed)
    y_train = np.loadtxt(f"{data_path}/train/y_train.txt", dtype=int) - 1
    y_test = np.loadtxt(f"{data_path}/test/y_test.txt", dtype=int) - 1

    return X_train, y_train, X_test, y_test


def extract_features_window(window):
    """
    Extract statistical features from a single window of sensor data.

    Features extracted:
    - Mean and std for each of 6 axes (12 features)
    - Min and max for each of 6 axes (12 features)
    - Mean absolute acceleration (1 feature)
    - Mean absolute gyroscope (1 feature)
    - Acceleration magnitude mean and std (2 features)

    Args:
        window: 2D array of shape (window_size, 6) containing sensor readings

    Returns:
        1D array of extracted features (length 28)
    """
    features = []

    # 1. Mean and standard deviation for each axis
    for axis in range(6):
        features.append(np.mean(window[:, axis]))
        features.append(np.std(window[:, axis]))

    # 2. Min and max for each axis
    for axis in range(6):
        features.append(np.min(window[:, axis]))
        features.append(np.max(window[:, axis]))

    # 3. Mean absolute acceleration (first 3 axes: accelerometer)
    features.append(np.sum(np.abs(window[:, :3])) / window.shape[0])

    # 4. Mean absolute gyroscope (last 3 axes: gyroscope)
    features.append(np.sum(np.abs(window[:, 3:])) / window.shape[0])

    # 5. Acceleration magnitude (Euclidean norm across x, y, z)
    acc_magnitude = np.linalg.norm(window[:, :3], axis=1)
    features.append(np.mean(acc_magnitude))
    features.append(np.std(acc_magnitude))

    return np.array(features)


def extract_features_dataset(X_raw):
    """
    Extract features from the entire dataset.

    Args:
        X_raw: Raw data of shape (num_samples, window_size, num_sensors)

    Returns:
        Feature matrix of shape (num_samples, num_features)
    """
    features_list = []
    for window in X_raw:
        features_list.append(extract_features_window(window))
    return np.array(features_list)
# Out:
# Requirement already satisfied: tensorflow-model-optimization in /usr/local/lib/python3.12/dist-packages (0.8.1)
# Requirement already satisfied: absl-py~=1.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.4.0)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.0.2)
# Requirement already satisfied: six~=1.14 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.17.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (1.16.3)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (0.1.10)
# Requirement already satisfied: mock in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (5.2.0)
# Requirement already satisfied: tf-keras>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (26.1.0)
# Requirement already satisfied: wrapt>=1.11.2 in /usr/local/lib/python3.12/dist-packages (from dm-tree~=0.1.1->tensorflow-model-optimization) (2.2.0)
# Requirement already satisfied: tensorflow<2.21,>=2.20 in /usr/local/lib/python3.12/dist-packages (from tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (75.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.15.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (1.80.0)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.13.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.15)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2026.5.20)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (11.3.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow<2.21,>=2.20->tf-keras>=2.14.1->tensorflow-model-optimization) (0.1.2)
# Requirement already satisfied: ai-edge-litert in /usr/local/lib/python3.12/dist-packages (2.1.5)
# Requirement already satisfied: backports.strenum in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (1.2.8)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (25.12.19)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (2.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.67.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (4.15.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from ai-edge-litert) (5.29.6)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (1.5.3)
# Mounted at /content/drive

# %%
# Load and Process Full Dataset (6-Class)
# ============================================================================

print("\n" + "="*60)
print("UCI HAR Dataset Loading")
print("="*60)

# Load raw data
X_train_raw, y_train, X_test_raw, y_test = load_uci_har_raw()

print(f"Training data shape: {X_train_raw.shape}")
print(f"Test data shape: {X_test_raw.shape}")

# Extract features from raw windows
X_train_feat = extract_features_dataset(X_train_raw)
X_test_feat = extract_features_dataset(X_test_raw)

print(f"\nExtracted features - train: {X_train_feat.shape}, test: {X_test_feat.shape}")

# Standardize features (zero mean, unit variance)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled = scaler.transform(X_test_feat)

print(f"Scaled features - train: {X_train_scaled.shape}, test: {X_test_scaled.shape}")

# Build and Train 6-Class Model

print("\n" + "="*60)
print("Building 6-Class Classification Model")
print("="*60)

# Define neural network architecture
complete_feature_model = models.Sequential([
    layers.Input(shape=(X_train_feat.shape[1],)),
    layers.Dense(32, activation="relu", name="dense_hidden"),
    layers.Dense(NUM_CLASSES, activation="softmax", name="dense_output"),
], name="complete_features_baseline")

# Compile the model
complete_feature_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Display model architecture
complete_feature_model.summary()

# Early stopping callback to prevent overfitting
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Train the model
history = complete_feature_model.fit(
    X_train_scaled, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_scaled, y_test),
    callbacks=[early_stop],
    verbose=1,
)

print("\nTraining completed!")

# Save 6-Class Model

# Save in Keras format (recommended for TensorFlow 2.x)
complete_feature_model.save(
    f"{project_path}/output/full_model/models/complete_features_baseline.keras"
)
print("\nSaved: complete_features_baseline.keras")

# Plot Training Curves for 6-Class Model

plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss', color='blue')
plt.plot(history.history['val_loss'], label='Validation Loss', color='orange')
plt.title('6-Class Model Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha=0.3)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('6-Class Model Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/training_curves.png", dpi=150)
plt.show()

print("Saved: training_curves.png")

# valuate 6-Class Model

print("\n" + "="*60)
print("6-Class Model Evaluation")
print("="*60)

# Generate predictions
y_pred = np.argmax(complete_feature_model.predict(X_test_scaled), axis=1)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=TARGET_NAMES))

# Confusion matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(
    cm, annot=True, fmt="d", cmap="Blues",
    xticklabels=TARGET_NAMES, yticklabels=TARGET_NAMES
)
plt.title("6-Class Confusion Matrix (Baseline Model)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/confusion_matrix.png", dpi=150)
plt.show()

print("Saved: confusion_matrix.png")

# Convert 6-Class Model to TFLite

print("\n" + "="*60)
print("6-Class Model TFLite Conversion")
print("="*60)

# Convert Keras model to TFLite format
converter_base = tf.lite.TFLiteConverter.from_keras_model(complete_feature_model)
tflite_base_model = converter_base.convert()

# Save the TFLite model
tflite_path = f"{project_path}/output/full_model/models/complete_features_model.tflite"
with open(tflite_path, "wb") as f:
    f.write(tflite_base_model)

print(f"Saved: complete_features_model.tflite")
print(f"File size: {os.path.getsize(tflite_path) / 1024:.2f} KB")

# Create Reduced Model (2-Class: Stationary vs Walking)

print("\n" + "="*60)
print("Creating Reduced 2-Class Model")
print("="*60)

def map_labels_to_binary(y):
    """
    Map original 6-class labels to binary classification:
    - WALKING, WALKING_UP, WALKING_DOWN → 1 (walking)
    - SITTING, STANDING, LAYING → 0 (stationary)

    Args:
        y: Array of original labels (0-5)

    Returns:
        Array of binary labels (0 or 1)
    """
    mapped = []
    for label in y:
        if label in [0, 1, 2]:      # Walking-related activities
            mapped.append(1)
        elif label in [3, 4, 5]:    # Stationary activities
            mapped.append(0)
    return np.array(mapped)


# Create binary labels
y_train_binary = map_labels_to_binary(y_train)
y_test_binary = map_labels_to_binary(y_test)
# Out:
# ============================================================
# UCI HAR Dataset Loading
# ============================================================
# Training data shape: (7352, 128, 6)
# Test data shape: (2947, 128, 6)
#
# Extracted features - train: (7352, 28), test: (2947, 28)
# Scaled features - train: (7352, 28), test: (2947, 28)
#
# ============================================================
# Building 6-Class Classification Model
# ============================================================
# Model: "complete_features_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_hidden (Dense)            │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,126 (4.40 KB)
#  Trainable params: 1,126 (4.40 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.4261 - loss: 1.1829 - val_accuracy: 0.5253 - val_loss: 1.0057
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.5492 - loss: 0.9284 - val_accuracy: 0.5850 - val_loss: 0.9056
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6002 - loss: 0.8474 - val_accuracy: 0.6050 - val_loss: 0.8492
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6246 - loss: 0.7993 - val_accuracy: 0.6176 - val_loss: 0.8107
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6420 - loss: 0.7665 - val_accuracy: 0.6328 - val_loss: 0.7824
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6567 - loss: 0.7416 - val_accuracy: 0.6481 - val_loss: 0.7602
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.6676 - loss: 0.7214 - val_accuracy: 0.6566 - val_loss: 0.7414
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.6797 - loss: 0.7042 - val_accuracy: 0.6624 - val_loss: 0.7254
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.6900 - loss: 0.6869 - val_accuracy: 0.6647 - val_loss: 0.7106
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7020 - loss: 0.6722 - val_accuracy: 0.6715 - val_loss: 0.6982
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7119 - loss: 0.6597 - val_accuracy: 0.6790 - val_loss: 0.6877
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7187 - loss: 0.6483 - val_accuracy: 0.6858 - val_loss: 0.6779
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7252 - loss: 0.6379 - val_accuracy: 0.6888 - val_loss: 0.6692
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7311 - loss: 0.6286 - val_accuracy: 0.6966 - val_loss: 0.6612
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7372 - loss: 0.6199 - val_accuracy: 0.7007 - val_loss: 0.6550
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7401 - loss: 0.6121 - val_accuracy: 0.7051 - val_loss: 0.6487
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7451 - loss: 0.6048 - val_accuracy: 0.7082 - val_loss: 0.6438
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7485 - loss: 0.5981 - val_accuracy: 0.7126 - val_loss: 0.6385
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7520 - loss: 0.5919 - val_accuracy: 0.7160 - val_loss: 0.6337
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7552 - loss: 0.5860 - val_accuracy: 0.7173 - val_loss: 0.6292
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7586 - loss: 0.5804 - val_accuracy: 0.7218 - val_loss: 0.6252
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7636 - loss: 0.5750 - val_accuracy: 0.7234 - val_loss: 0.6210
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7669 - loss: 0.5699 - val_accuracy: 0.7282 - val_loss: 0.6171
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7709 - loss: 0.5650 - val_accuracy: 0.7309 - val_loss: 0.6139
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7734 - loss: 0.5604 - val_accuracy: 0.7346 - val_loss: 0.6104
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7753 - loss: 0.5559 - val_accuracy: 0.7367 - val_loss: 0.6076
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7776 - loss: 0.5516 - val_accuracy: 0.7377 - val_loss: 0.6045
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7802 - loss: 0.5474 - val_accuracy: 0.7404 - val_loss: 0.6017
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7818 - loss: 0.5433 - val_accuracy: 0.7418 - val_loss: 0.5997
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7852 - loss: 0.5397 - val_accuracy: 0.7452 - val_loss: 0.5961
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7875 - loss: 0.5359 - val_accuracy: 0.7486 - val_loss: 0.5933
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7892 - loss: 0.5323 - val_accuracy: 0.7536 - val_loss: 0.5912
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7901 - loss: 0.5288 - val_accuracy: 0.7557 - val_loss: 0.5901
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7927 - loss: 0.5255 - val_accuracy: 0.7574 - val_loss: 0.5883
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.5221 - val_accuracy: 0.7591 - val_loss: 0.5857
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7949 - loss: 0.5187 - val_accuracy: 0.7638 - val_loss: 0.5832
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7964 - loss: 0.5155 - val_accuracy: 0.7672 - val_loss: 0.5811
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7986 - loss: 0.5124 - val_accuracy: 0.7676 - val_loss: 0.5803
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7999 - loss: 0.5095 - val_accuracy: 0.7689 - val_loss: 0.5784
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8032 - loss: 0.5065 - val_accuracy: 0.7720 - val_loss: 0.5768
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8029 - loss: 0.5038 - val_accuracy: 0.7747 - val_loss: 0.5745
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8058 - loss: 0.5009 - val_accuracy: 0.7750 - val_loss: 0.5731
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8063 - loss: 0.4983 - val_accuracy: 0.7784 - val_loss: 0.5709
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8074 - loss: 0.4955 - val_accuracy: 0.7774 - val_loss: 0.5705
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8090 - loss: 0.4931 - val_accuracy: 0.7791 - val_loss: 0.5694
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8101 - loss: 0.4906 - val_accuracy: 0.7828 - val_loss: 0.5678
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8119 - loss: 0.4880 - val_accuracy: 0.7842 - val_loss: 0.5663
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8130 - loss: 0.4856 - val_accuracy: 0.7845 - val_loss: 0.5652
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8138 - loss: 0.4832 - val_accuracy: 0.7859 - val_loss: 0.5642
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8141 - loss: 0.4808 - val_accuracy: 0.7869 - val_loss: 0.5628
# Restoring model weights from the end of the best epoch: 50.
#
# Training completed!
#
# Saved: complete_features_baseline.keras
# Saved: training_curves.png
#
# ============================================================
# 6-Class Model Evaluation
# ============================================================
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      WALKING       0.86      0.85      0.86       496
#   WALKING_UP       0.80      0.85      0.82       471
# WALKING_DOWN       0.93      0.89      0.91       420
#      SITTING       0.76      0.58      0.66       491
#     STANDING       0.83      0.67      0.74       532
#       LAYING       0.64      0.90      0.75       537
#
#     accuracy                           0.79      2947
#    macro avg       0.80      0.79      0.79      2947
# weighted avg       0.80      0.79      0.79      2947
# Saved: confusion_matrix.png
#
# ============================================================
# 6-Class Model TFLite Conversion
# ============================================================
# Saved artifact at '/tmp/tmpawmyptkq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28), dtype=tf.float32, name='keras_tensor_12')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   133890506856144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890506860176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890506851920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890506855952: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved: complete_features_model.tflite
# File size: 6.26 KB
#
# ============================================================
# Creating Reduced 2-Class Model
# ============================================================

# %%
# Define class names for reduced model
TARGET_NAMES_REDUCED = ["STATIONARY", "WALKING"]

print(f"Original classes: {np.unique(y_train)}")
print(f"Binary classes: {np.unique(y_train_binary)}")
print(f"Training samples: {len(y_train_binary)}")
print(f"Test samples: {len(y_test_binary)}")

# Build reduced model architecture (same as original, but 2 outputs)
reduced_model = models.Sequential([
    layers.Input(shape=(X_train_scaled.shape[1],)),
    layers.Dense(32, activation="relu", name="dense_hidden"),
    layers.Dense(2, activation="softmax", name="dense_output"),
], name="reduced_features_baseline")

# Compile reduced model
reduced_model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# Display model architecture
reduced_model.summary()

# Train Reduced Model

print("\n" + "="*60)
print("Training Reduced 2-Class Model")
print("="*60)

# Early stopping callback
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
    verbose=1
)

# Train the reduced model
history_reduced = reduced_model.fit(
    X_train_scaled, y_train_binary,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_scaled, y_test_binary),
    callbacks=[early_stop],
    verbose=1
)

print("\nTraining completed!")

# Plot Training Curves for Reduced Model

plt.figure(figsize=(12, 5))

# Loss plot
plt.subplot(1, 2, 1)
plt.plot(history_reduced.history['loss'], label='Train Loss', color='blue')
plt.plot(history_reduced.history['val_loss'], label='Validation Loss', color='orange')
plt.title('Reduced Model (2-Class) Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(alpha=0.3)

# Accuracy plot
plt.subplot(1, 2, 2)
plt.plot(history_reduced.history['accuracy'], label='Train Accuracy', color='blue')
plt.plot(history_reduced.history['val_accuracy'], label='Validation Accuracy', color='orange')
plt.title('Reduced Model (2-Class) Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(alpha=0.3)

plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_training_curves.png", dpi=150)
plt.show()

print("Saved: reduced_training_curves.png")

# Evaluate Reduced Model

print("\n" + "="*60)
print("Reduced Model (2-Class) Evaluation")
print("="*60)

# Generate predictions
y_pred_reduced = np.argmax(reduced_model.predict(X_test_scaled), axis=1)

# Classification report
print("\nClassification Report (2-Class):")
print(classification_report(y_test_binary, y_pred_reduced, target_names=TARGET_NAMES_REDUCED))

# Confusion matrix
cm_reduced = confusion_matrix(y_test_binary, y_pred_reduced)

plt.figure(figsize=(6, 5))
sns.heatmap(
    cm_reduced, annot=True, fmt="d", cmap="Blues",
    xticklabels=TARGET_NAMES_REDUCED, yticklabels=TARGET_NAMES_REDUCED
)
plt.title("Reduced Model (2-Class) Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_confusion_matrix.png", dpi=150)
plt.show()

print("Saved: reduced_confusion_matrix.png")

# Save Reduced Model and Convert to TFLite

print("\n" + "="*60)
print("Saving Reduced Model and TFLite Conversion")
print("="*60)

# Save Keras model
reduced_model.save(f"{project_path}/output/reduced/models/reduced_features_baseline.keras")
print("Saved: reduced_features_baseline.keras")

# Convert to TFLite
converter = tf.lite.TFLiteConverter.from_keras_model(reduced_model)
tflite_reduced_model = converter.convert()

# Save TFLite model
tflite_reduced_path = f"{project_path}/output/reduced/models/reduced_features_baseline.tflite"
with open(tflite_reduced_path, "wb") as f:
    f.write(tflite_reduced_model)

print(f"Saved: reduced_features_baseline.tflite")
print(f"File size: {os.path.getsize(tflite_reduced_path) / 1024:.2f} KB")

# Save Scaler Parameters (for inference on device)

print("\n" + "="*60)
print("Saving Scaler Configuration")
print("="*60)

# Export scaler parameters as JSON for use on device
scaler_params = {
    "mean": scaler.mean_.tolist(),
    "scale": scaler.scale_.tolist(),
    "feature_names": [f"feature_{i}" for i in range(X_train_feat.shape[1])]
}

scaler_json_path = f"{project_path}/output/reduced/models/scaler_params.json"
with open(scaler_json_path, "w") as f:
    json.dump(scaler_params, f, indent=4)

print(f"Saved: scaler_params.json")

# Also save using joblib for Python inference
import joblib
joblib.dump(scaler, f"{project_path}/output/reduced/models/scaler.pkl")
print("Saved: scaler.pkl")

# Final Summary Report

print("\n" + "="*60)
print("Pipeline Complete - Summary Report")
print("="*60)

print("\n📊 MODEL PERFORMANCE SUMMARY:")
print(f"6-Class Model - Test Accuracy: {history.history['val_accuracy'][-1]:.4f}")
print(f"2-Class Model - Test Accuracy: {history_reduced.history['val_accuracy'][-1]:.4f}")

print("\n MODEL FILE SIZES:")
print(f"6-Class TFLite: {os.path.getsize(tflite_path) / 1024:.2f} KB")
print(f"2-Class TFLite: {os.path.getsize(tflite_reduced_path) / 1024:.2f} KB")

print("\nPipeline completed successfully!")
# Out:
# Original classes: [0 1 2 3 4 5]
# Binary classes: [0 1]
# Training samples: 7352
# Test samples: 2947
# Model: "reduced_features_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_hidden (Dense)            │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_output (Dense)            │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 994 (3.88 KB)
#  Trainable params: 994 (3.88 KB)
#  Non-trainable params: 0 (0.00 B)
# ============================================================
# Training Reduced 2-Class Model
# ============================================================
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9467 - loss: 0.1355 - val_accuracy: 0.9986 - val_loss: 0.0219
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9984 - loss: 0.0126 - val_accuracy: 0.9993 - val_loss: 0.0102
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9990 - loss: 0.0069 - val_accuracy: 0.9993 - val_loss: 0.0066
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9995 - loss: 0.0048 - val_accuracy: 0.9997 - val_loss: 0.0049
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9995 - loss: 0.0037 - val_accuracy: 0.9997 - val_loss: 0.0039
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9995 - loss: 0.0028 - val_accuracy: 0.9997 - val_loss: 0.0033
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9997 - loss: 0.0023 - val_accuracy: 0.9997 - val_loss: 0.0028
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9999 - loss: 0.0020 - val_accuracy: 0.9997 - val_loss: 0.0025
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 0.9997 - val_loss: 0.0022
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 0.9997 - val_loss: 0.0020
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 0.9997 - val_loss: 0.0018
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 0.9997 - val_loss: 0.0017
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 0.9997 - val_loss: 0.0015
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9999 - loss: 8.9604e-04 - val_accuracy: 0.9997 - val_loss: 0.0014
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 7.1631e-04 - val_accuracy: 0.9997 - val_loss: 0.0013
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 5.6581e-04 - val_accuracy: 0.9997 - val_loss: 0.0012
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9999 - loss: 4.5221e-04 - val_accuracy: 0.9997 - val_loss: 0.0012
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.5827e-04 - val_accuracy: 0.9997 - val_loss: 0.0011
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.0248e-04 - val_accuracy: 0.9997 - val_loss: 0.0011
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5266e-04 - val_accuracy: 0.9997 - val_loss: 9.8473e-04
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 2.1359e-04 - val_accuracy: 0.9997 - val_loss: 9.2423e-04
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.8312e-04 - val_accuracy: 0.9997 - val_loss: 8.6082e-04
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5591e-04 - val_accuracy: 0.9997 - val_loss: 8.0357e-04
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3513e-04 - val_accuracy: 0.9997 - val_loss: 7.4318e-04
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1612e-04 - val_accuracy: 0.9997 - val_loss: 6.8653e-04
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 9.9697e-05 - val_accuracy: 0.9997 - val_loss: 6.3824e-04
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.7395e-05 - val_accuracy: 0.9997 - val_loss: 5.8526e-04
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.4926e-05 - val_accuracy: 0.9997 - val_loss: 5.4133e-04
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.5633e-05 - val_accuracy: 0.9997 - val_loss: 4.9080e-04
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.7346e-05 - val_accuracy: 0.9997 - val_loss: 4.4675e-04
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.9782e-05 - val_accuracy: 0.9997 - val_loss: 4.0900e-04
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.3834e-05 - val_accuracy: 0.9997 - val_loss: 3.6810e-04
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 1.0000 - loss: 3.7888e-05 - val_accuracy: 0.9997 - val_loss: 3.3233e-04
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 3.3423e-05 - val_accuracy: 1.0000 - val_loss: 2.9720e-04
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.9095e-05 - val_accuracy: 1.0000 - val_loss: 2.6795e-04
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.5740e-05 - val_accuracy: 1.0000 - val_loss: 2.3647e-04
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 2.2422e-05 - val_accuracy: 1.0000 - val_loss: 2.1001e-04
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.9656e-05 - val_accuracy: 1.0000 - val_loss: 1.8635e-04
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.7312e-05 - val_accuracy: 1.0000 - val_loss: 1.6526e-04
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.5147e-05 - val_accuracy: 1.0000 - val_loss: 1.4760e-04
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.3335e-05 - val_accuracy: 1.0000 - val_loss: 1.3027e-04
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.1577e-05 - val_accuracy: 1.0000 - val_loss: 1.1517e-04
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 1.0359e-05 - val_accuracy: 1.0000 - val_loss: 1.0279e-04
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 8.9528e-06 - val_accuracy: 1.0000 - val_loss: 9.2185e-05
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 7.9487e-06 - val_accuracy: 1.0000 - val_loss: 8.2366e-05
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.9371e-06 - val_accuracy: 1.0000 - val_loss: 7.4111e-05
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 6.1096e-06 - val_accuracy: 1.0000 - val_loss: 6.6795e-05
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 5.3432e-06 - val_accuracy: 1.0000 - val_loss: 5.9991e-05
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.7298e-06 - val_accuracy: 1.0000 - val_loss: 5.4342e-05
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 4.1538e-06 - val_accuracy: 1.0000 - val_loss: 4.9420e-05
# Restoring model weights from the end of the best epoch: 50.
#
# Training completed!
# Saved: reduced_training_curves.png
#
# ============================================================
# Reduced Model (2-Class) Evaluation
# ============================================================
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# Classification Report (2-Class):
#               precision    recall  f1-score   support
#
#   STATIONARY       1.00      1.00      1.00      1560
#      WALKING       1.00      1.00      1.00      1387
#
#     accuracy                           1.00      2947
#    macro avg       1.00      1.00      1.00      2947
# weighted avg       1.00      1.00      1.00      2947
# Saved: reduced_confusion_matrix.png
#
# ============================================================
# Saving Reduced Model and TFLite Conversion
# ============================================================
# Saved: reduced_features_baseline.keras
# Saved artifact at '/tmp/tmp96xl4ges'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 28), dtype=tf.float32, name='keras_tensor_15')
# Output Type:
#   TensorSpec(shape=(None, 2), dtype=tf.float32, name=None)
# Captures:
#   133890515945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890382928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890382926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133890382933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Saved: reduced_features_baseline.tflite
# File size: 5.74 KB
#
# ============================================================
# Saving Scaler Configuration
# ============================================================
# Saved: scaler_params.json
# Saved: scaler.pkl
#
# ============================================================
# Pipeline Complete - Summary Report
# ============================================================
#
# 📊 MODEL PERFORMANCE SUMMARY:
# 6-Class Model - Test Accuracy: 0.7869
# 2-Class Model - Test Accuracy: 1.0000
#
#  MODEL FILE SIZES:
# 6-Class TFLite: 6.26 KB
# 2-Class TFLite: 5.74 KB
#
# Pipeline completed successfully!
