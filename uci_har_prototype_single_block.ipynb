# %%
# uci_har_prototype.py
# UCI HAR baseline prototype: 6-class model for domain validation only.

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Declare project home directory
project_path = "/content/drive/My Drive/AG/FH/study/AI_IoT/node/milestone2"
os.makedirs(project_path, exist_ok=True)

# Create output directory
os.makedirs(f"{project_path}/output/reduced", exist_ok=True)
os.makedirs(f"{project_path}/output/reduced/models", exist_ok=True)
os.makedirs(f"{project_path}/output/full_model", exist_ok=True)
os.makedirs(f"{project_path}/output/full_model/models", exist_ok=True)



# Reproducibility
np.random.seed(42)
tf.random.set_seed(42)

TARGET_NAMES = ["WALKING", "WALKING_UP", "WALKING_DOWN", "SITTING", "STANDING", "LAYING"]
NUM_CLASSES  = 6

# Data loading
def load_uci_har_raw(data_path=f"{project_path}/UCI-HAR_Dataset"):
    acc_axes  = ["body_acc_x",  "body_acc_y",  "body_acc_z"]
    gyro_axes = ["body_gyro_x", "body_gyro_y", "body_gyro_z"]

    def _load_split(split):
        arrays = []
        for name in acc_axes + gyro_axes:
            path = f"{data_path}/{split}/InertialSignals/{name}_{split}.txt"
            arrays.append(np.loadtxt(path))
        return np.stack(arrays, axis=-1)

    X_train = _load_split("train")
    X_test  = _load_split("test")

    y_train = np.loadtxt(f"{data_path}/train/y_train.txt", dtype=int)
    y_test  = np.loadtxt(f"{data_path}/test/y_test.txt", dtype=int)

    y_train -= 1
    y_test  -= 1

    return X_train, y_train, X_test, y_test

#  Feature extraction
def extract_features_window(window):
    feats = []
    for axis in range(6):
        feats.append(np.mean(window[:, axis]))
        feats.append(np.std(window[:, axis]))
    for axis in range(6):
        feats.append(np.min(window[:, axis]))
        feats.append(np.max(window[:, axis]))

    feats.append(np.sum(np.abs(window[:, :3])) / window.shape[0])
    feats.append(np.sum(np.abs(window[:, 3:])) / window.shape[0])

    acc_mag = np.linalg.norm(window[:, :3], axis=1)
    feats.append(np.mean(acc_mag))
    feats.append(np.std(acc_mag))

    return np.array(feats)

# ── Train Models
X_train_raw, y_train, X_test_raw, y_test = load_uci_har_raw()

X_train_feat = np.array([extract_features_window(w) for w in X_train_raw])
X_test_feat  = np.array([extract_features_window(w) for w in X_test_raw])

print(f"Feature shape - train: {X_train_feat.shape}, test: {X_test_feat.shape}")

scaler = StandardScaler()
X_train_sc = scaler.fit_transform(X_train_feat)
X_test_sc  = scaler.transform(X_test_feat)

model = models.Sequential([
    layers.Input(shape=(X_train_feat.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(NUM_CLASSES, activation="softmax"),
], name="uci_har_baseline")

model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()

early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history = model.fit(
    X_train_sc, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_sc, y_test),
    callbacks=[early_stop],
    verbose=1,
)


# Ploting Training vs Validation Loss & Accuracy
plt.figure(figsize=(12,8))

# Loss plot
plt.subplot(1,2,1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig(f"{project_path}/output/full_model/training_validation_curves.png", dpi=150)
plt.show()


# Accuracy plot
plt.subplot(1,2,2)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/training_curves.png", dpi=150)
plt.show()

print("Saved training_curves.png")


# ── Evaluation
y_pred = np.argmax(model.predict(X_test_sc), axis=1)

print("\n" + classification_report(y_test, y_pred, target_names=TARGET_NAMES))

cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d",
            xticklabels=TARGET_NAMES,
            yticklabels=TARGET_NAMES,
            cmap="Blues")

plt.title("UCI HAR Confusion Matrix (Baseline model)")
plt.tight_layout()
plt.savefig(f"{project_path}/output/full_model/uci_har_confusion_matrix.png", dpi=150)
plt.show()

print("Saved uci_har_confusion_matrix.png")

# Save Model
model.save(f"{project_path}/output/full_model/models/uci_har_baseline.keras")
print("Saved uci_har_baseline.keras")


## Reduced Model

# 1. Label Mapping (6 → 2 classes)
# 0: stationary, 1: walking

def map_labels(y):
    mapped = []
    for label in y:
        if label in [0, 1, 2]:      # WALKING variants
            mapped.append(1)        # walking
        elif label in [3, 4, 5]:    # SITTING/STANDING/LAYING
            mapped.append(0)        # stationary
    return np.array(mapped)

y_train_mapped = map_labels(y_train)
y_test_mapped  = map_labels(y_test)

TARGET_NAMES_REDUCED = ["STATIONARY", "WALKING"]

print("Original classes:", np.unique(y_train))
print("Mapped classes:", np.unique(y_train_mapped))


# 2. Build Reduced Model
model_reduced = models.Sequential([
    layers.Input(shape=(X_train_sc.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(2, activation="softmax"),
], name="uci_har_reduced_baseline")

model_reduced.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model_reduced.summary()



# Train
early_stop = callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True
)

history_reduced = model_reduced.fit(
    X_train_sc, y_train_mapped,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_sc, y_test_mapped),
    callbacks=[early_stop],
    verbose=1
)


# Plot Training Curves
plt.figure(figsize=(12,5))

# Loss
plt.subplot(1,2,1)
plt.plot(history_reduced.history['loss'], label='Train Loss')
plt.plot(history_reduced.history['val_loss'], label='Validation Loss')
plt.title('Reduced Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Accuracy
plt.subplot(1,2,2)
plt.plot(history_reduced.history['accuracy'], label='Train Accuracy')
plt.plot(history_reduced.history['val_accuracy'], label='Validation Accuracy')
plt.title('Reduced Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_training_curves.png", dpi=150)
plt.show()

print("Saved reduced_training_curves.png")


# 5. Evaluation
y_pred_reduced = np.argmax(model_reduced.predict(X_test_sc), axis=1)

print("\nReduced Model Classification Report:\n")
print(classification_report(y_test_mapped, y_pred_reduced, target_names=TARGET_NAMES_REDUCED))

cm_reduced = confusion_matrix(y_test_mapped, y_pred_reduced)

plt.figure(figsize=(6,5))
sns.heatmap(cm_reduced, annot=True, fmt="d",
            xticklabels=TARGET_NAMES_REDUCED,
            yticklabels=TARGET_NAMES_REDUCED,
            cmap="Blues")

plt.title("Reduced-Class Confusion Matrix (UCI Baseline)")
plt.tight_layout()
plt.savefig(f"{project_path}/output/reduced/reduced_confusion_matrix.png", dpi=150)
plt.show()

print("Saved reduced_confusion_matrix.png")

# . Save Model
model_reduced.save(f"{project_path}/output/reduced/models/uci_har_reduced_baseline.keras")
print("Saved uci_har_reduced_baseline.keras")
# Out:
# Mounted at /content/drive
# Feature shape - train: (7352, 28), test: (2947, 28)
# Model: "uci_har_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 6)              │           198 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,126 (4.40 KB)
#  Trainable params: 1,126 (4.40 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.4291 - loss: 1.1538 - val_accuracy: 0.4981 - val_loss: 0.9977
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5535 - loss: 0.9221 - val_accuracy: 0.5612 - val_loss: 0.9000
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5953 - loss: 0.8398 - val_accuracy: 0.5881 - val_loss: 0.8407
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6262 - loss: 0.7911 - val_accuracy: 0.6074 - val_loss: 0.8044
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6400 - loss: 0.7612 - val_accuracy: 0.6223 - val_loss: 0.7783
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6525 - loss: 0.7395 - val_accuracy: 0.6376 - val_loss: 0.7586
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6643 - loss: 0.7223 - val_accuracy: 0.6417 - val_loss: 0.7425
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6730 - loss: 0.7078 - val_accuracy: 0.6495 - val_loss: 0.7290
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6802 - loss: 0.6953 - val_accuracy: 0.6556 - val_loss: 0.7166
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6911 - loss: 0.6841 - val_accuracy: 0.6607 - val_loss: 0.7061
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6971 - loss: 0.6738 - val_accuracy: 0.6658 - val_loss: 0.6965
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7040 - loss: 0.6644 - val_accuracy: 0.6695 - val_loss: 0.6878
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7103 - loss: 0.6557 - val_accuracy: 0.6753 - val_loss: 0.6797
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7157 - loss: 0.6477 - val_accuracy: 0.6787 - val_loss: 0.6724
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7212 - loss: 0.6402 - val_accuracy: 0.6841 - val_loss: 0.6656
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7257 - loss: 0.6331 - val_accuracy: 0.6871 - val_loss: 0.6596
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7292 - loss: 0.6264 - val_accuracy: 0.6929 - val_loss: 0.6541
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7348 - loss: 0.6200 - val_accuracy: 0.6953 - val_loss: 0.6491
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7399 - loss: 0.6136 - val_accuracy: 0.6983 - val_loss: 0.6443
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7462 - loss: 0.6073 - val_accuracy: 0.7004 - val_loss: 0.6402
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7520 - loss: 0.6011 - val_accuracy: 0.7007 - val_loss: 0.6364
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7564 - loss: 0.5950 - val_accuracy: 0.7038 - val_loss: 0.6323
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7602 - loss: 0.5892 - val_accuracy: 0.7068 - val_loss: 0.6286
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7633 - loss: 0.5836 - val_accuracy: 0.7099 - val_loss: 0.6251
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7667 - loss: 0.5783 - val_accuracy: 0.7153 - val_loss: 0.6211
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7692 - loss: 0.5731 - val_accuracy: 0.7167 - val_loss: 0.6185
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7709 - loss: 0.5680 - val_accuracy: 0.7177 - val_loss: 0.6155
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7733 - loss: 0.5630 - val_accuracy: 0.7194 - val_loss: 0.6128
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7768 - loss: 0.5583 - val_accuracy: 0.7224 - val_loss: 0.6101
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7791 - loss: 0.5537 - val_accuracy: 0.7275 - val_loss: 0.6080
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7807 - loss: 0.5494 - val_accuracy: 0.7313 - val_loss: 0.6062
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7840 - loss: 0.5453 - val_accuracy: 0.7353 - val_loss: 0.6042
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7863 - loss: 0.5412 - val_accuracy: 0.7370 - val_loss: 0.6022
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7881 - loss: 0.5374 - val_accuracy: 0.7401 - val_loss: 0.6003
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7897 - loss: 0.5334 - val_accuracy: 0.7435 - val_loss: 0.5984
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7918 - loss: 0.5298 - val_accuracy: 0.7472 - val_loss: 0.5970
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7945 - loss: 0.5261 - val_accuracy: 0.7489 - val_loss: 0.5956
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7958 - loss: 0.5228 - val_accuracy: 0.7526 - val_loss: 0.5943
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7971 - loss: 0.5195 - val_accuracy: 0.7560 - val_loss: 0.5931
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7982 - loss: 0.5164 - val_accuracy: 0.7536 - val_loss: 0.5926
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7986 - loss: 0.5132 - val_accuracy: 0.7598 - val_loss: 0.5916
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8007 - loss: 0.5100 - val_accuracy: 0.7618 - val_loss: 0.5902
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8014 - loss: 0.5071 - val_accuracy: 0.7645 - val_loss: 0.5897
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8028 - loss: 0.5042 - val_accuracy: 0.7652 - val_loss: 0.5886
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8040 - loss: 0.5014 - val_accuracy: 0.7659 - val_loss: 0.5876
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8041 - loss: 0.4988 - val_accuracy: 0.7672 - val_loss: 0.5876
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8048 - loss: 0.4961 - val_accuracy: 0.7679 - val_loss: 0.5871
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8052 - loss: 0.4938 - val_accuracy: 0.7706 - val_loss: 0.5869
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8055 - loss: 0.4914 - val_accuracy: 0.7699 - val_loss: 0.5866
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8067 - loss: 0.4889 - val_accuracy: 0.7720 - val_loss: 0.5862
# Saved training_curves.png
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
#               precision    recall  f1-score   support
#
#      WALKING       0.83      0.86      0.85       496
#   WALKING_UP       0.80      0.82      0.81       471
# WALKING_DOWN       0.94      0.90      0.92       420
#      SITTING       0.77      0.58      0.66       491
#     STANDING       0.85      0.59      0.69       532
#       LAYING       0.60      0.91      0.72       537
#
#     accuracy                           0.77      2947
#    macro avg       0.80      0.78      0.78      2947
# weighted avg       0.79      0.77      0.77      2947
# Saved uci_har_confusion_matrix.png
# Saved uci_har_baseline.keras
# Original classes: [0 1 2 3 4 5]
# Mapped classes: [0 1]
# Model: "uci_har_reduced_baseline"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 32)             │           928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │            66 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 994 (3.88 KB)
#  Trainable params: 994 (3.88 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9721 - loss: 0.0869 - val_accuracy: 0.9990 - val_loss: 0.0171
# Epoch 2/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9989 - loss: 0.0089 - val_accuracy: 0.9990 - val_loss: 0.0084
# Epoch 3/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0050 - val_accuracy: 0.9990 - val_loss: 0.0056
# Epoch 4/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0037 - val_accuracy: 0.9993 - val_loss: 0.0041
# Epoch 5/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9997 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 6/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9997 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 7/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 8/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 9/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0015
# Epoch 10/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 11/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 12/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 0.0010
# Epoch 13/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9999 - loss: 8.6428e-04 - val_accuracy: 1.0000 - val_loss: 9.0963e-04
# Epoch 14/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9999 - loss: 6.9105e-04 - val_accuracy: 1.0000 - val_loss: 8.1316e-04
# Epoch 15/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9999 - loss: 5.3726e-04 - val_accuracy: 1.0000 - val_loss: 7.2596e-04
# Epoch 16/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.2282e-04 - val_accuracy: 1.0000 - val_loss: 6.4697e-04
# Epoch 17/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.4507e-04 - val_accuracy: 1.0000 - val_loss: 5.7761e-04
# Epoch 18/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.9028e-04 - val_accuracy: 1.0000 - val_loss: 5.2211e-04
# Epoch 19/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.4331e-04 - val_accuracy: 1.0000 - val_loss: 4.7076e-04
# Epoch 20/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 2.0613e-04 - val_accuracy: 1.0000 - val_loss: 4.2798e-04
# Epoch 21/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 1.7665e-04 - val_accuracy: 1.0000 - val_loss: 3.8933e-04
# Epoch 22/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.5129e-04 - val_accuracy: 1.0000 - val_loss: 3.5597e-04
# Epoch 23/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.3013e-04 - val_accuracy: 1.0000 - val_loss: 3.2687e-04
# Epoch 24/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.1256e-04 - val_accuracy: 1.0000 - val_loss: 2.9802e-04
# Epoch 25/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 9.6757e-05 - val_accuracy: 1.0000 - val_loss: 2.7253e-04
# Epoch 26/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.5486e-05 - val_accuracy: 1.0000 - val_loss: 2.5352e-04
# Epoch 27/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 7.3513e-05 - val_accuracy: 1.0000 - val_loss: 2.3216e-04
# Epoch 28/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 1.0000 - loss: 6.4190e-05 - val_accuracy: 1.0000 - val_loss: 2.1543e-04
# Epoch 29/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 5.5853e-05 - val_accuracy: 1.0000 - val_loss: 1.9937e-04
# Epoch 30/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.8272e-05 - val_accuracy: 1.0000 - val_loss: 1.8533e-04
# Epoch 31/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.2540e-05 - val_accuracy: 1.0000 - val_loss: 1.7449e-04
# Epoch 32/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.6967e-05 - val_accuracy: 1.0000 - val_loss: 1.6148e-04
# Epoch 33/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 3.2276e-05 - val_accuracy: 1.0000 - val_loss: 1.5069e-04
# Epoch 34/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.7978e-05 - val_accuracy: 1.0000 - val_loss: 1.4086e-04
# Epoch 35/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.4561e-05 - val_accuracy: 1.0000 - val_loss: 1.3246e-04
# Epoch 36/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 2.1399e-05 - val_accuracy: 1.0000 - val_loss: 1.2451e-04
# Epoch 37/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.8711e-05 - val_accuracy: 1.0000 - val_loss: 1.1515e-04
# Epoch 38/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.6422e-05 - val_accuracy: 1.0000 - val_loss: 1.0872e-04
# Epoch 39/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.4337e-05 - val_accuracy: 1.0000 - val_loss: 1.0160e-04
# Epoch 40/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 1.2596e-05 - val_accuracy: 1.0000 - val_loss: 9.6420e-05
# Epoch 41/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 1.0944e-05 - val_accuracy: 1.0000 - val_loss: 8.9383e-05
# Epoch 42/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 9.6975e-06 - val_accuracy: 1.0000 - val_loss: 8.5314e-05
# Epoch 43/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 8.4643e-06 - val_accuracy: 1.0000 - val_loss: 8.1436e-05
# Epoch 44/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 7.4019e-06 - val_accuracy: 1.0000 - val_loss: 7.6372e-05
# Epoch 45/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 6.5049e-06 - val_accuracy: 1.0000 - val_loss: 7.2826e-05
# Epoch 46/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 5.6934e-06 - val_accuracy: 1.0000 - val_loss: 6.9643e-05
# Epoch 47/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 1.0000 - loss: 4.9933e-06 - val_accuracy: 1.0000 - val_loss: 6.5762e-05
# Epoch 48/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 4.4033e-06 - val_accuracy: 1.0000 - val_loss: 6.3190e-05
# Epoch 49/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.8564e-06 - val_accuracy: 1.0000 - val_loss: 5.9437e-05
# Epoch 50/50
# 230/230 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 3.4025e-06 - val_accuracy: 1.0000 - val_loss: 5.7391e-05
# Saved reduced_training_curves.png
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Reduced Model Classification Report:
#
#               precision    recall  f1-score   support
#
#   STATIONARY       1.00      1.00      1.00      1560
#      WALKING       1.00      1.00      1.00      1387
#
#     accuracy                           1.00      2947
#    macro avg       1.00      1.00      1.00      2947
# weighted avg       1.00      1.00      1.00      2947
# Saved reduced_confusion_matrix.png
# Saved uci_har_reduced_baseline.keras
